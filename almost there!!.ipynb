# %% [markdown]
# # Getting The Data

# %%
import pandas as pd
ghi_df = pd.read_csv('/content/drive/MyDrive/predicted_ghi.csv')
print(ghi_df)
# Out:
#     hour  predicted_ghi        date
# 0      0       0.000000  2025-10-09
# 1      1       0.000000  2025-10-09
# 2      2       0.000000  2025-10-09
# 3      3       0.000000  2025-10-09
# 4      4       0.000000  2025-10-09
# 5      5       0.000000  2025-10-09
# 6      6       0.000000  2025-10-09
# 7      7      65.597340  2025-10-09
# 8      8     174.463470  2025-10-09
# 9      9     298.220580  2025-10-09
# 10    10     443.440770  2025-10-09
# 11    11     560.139600  2025-10-09
# 12    12     639.329400  2025-10-09
# 13    13     648.836400  2025-10-09
# 14    14     606.947630  2025-10-09
# 15    15     491.622770  2025-10-09
# 16    16     326.187070  2025-10-09
# 17    17     157.321370  2025-10-09
# 18    18      38.067554  2025-10-09
# 19    19       0.000000  2025-10-09
# 20    20       0.000000  2025-10-09
# 21    21       0.000000  2025-10-09
# 22    22       0.000000  2025-10-09
# 23    23       0.000000  2025-10-09

# %%
import pandas as pd
load_df = pd.read_csv('/content/drive/MyDrive/predicted_load.csv')
print(load_df)
# Out:
#     hour  predicted_load        date
# 0      0       7685.0930  2025-10-09
# 1      1       7156.7070  2025-10-09
# 2      2       6732.7060  2025-10-09
# 3      3       6442.0140  2025-10-09
# 4      4       6328.8784  2025-10-09
# 5      5       6341.0220  2025-10-09
# 6      6       6510.8657  2025-10-09
# 7      7       6838.9023  2025-10-09
# 8      8       7046.9490  2025-10-09
# 9      9       7328.2065  2025-10-09
# 10    10       7572.7905  2025-10-09
# 11    11       7843.7420  2025-10-09
# 12    12       8167.2134  2025-10-09
# 13    13       8484.8960  2025-10-09
# 14    14       8830.7280  2025-10-09
# 15    15       9254.6880  2025-10-09
# 16    16       9659.0670  2025-10-09
# 17    17      10019.4470  2025-10-09
# 18    18      10153.8430  2025-10-09
# 19    19       9991.4900  2025-10-09
# 20    20       9671.2020  2025-10-09
# 21    21       9373.9290  2025-10-09
# 22    22       8919.2650  2025-10-09
# 23    23       8334.5970  2025-10-09

# %% [markdown]
# # To Find PV and Battery Sizes

# %%
battery_capacity_list = []
final_PV_plant_m2_list = []

def simulate_day(target_date, seasonal_load_df, seasonal_ghi_df):
    load_day = seasonal_load_df[seasonal_load_df['date'] == target_date].reset_index(drop=True)
    ghi_day = seasonal_ghi_df[seasonal_ghi_df['date'] == target_date].reset_index(drop=True)

    '''Finding the Final Solar Photovoltaic Plant in m²'''
    PV_with_bonus = 0.20 * 1.31
    PR = 0.786
    daily_load_Wh = sum(load_day.iloc[:,1]) * 1_000_000
    daily_GHI_Wh_m2 = sum(ghi_day.iloc[:,1])

    final_PV_plant_m2 = daily_load_Wh / (daily_GHI_Wh_m2 * PV_with_bonus * PR)
    final_PV_plant_m2_list.append(final_PV_plant_m2)

    print(f'Solar PV Plant Size {final_PV_plant_m2:.2f} m²\n')

    '''Hourly Solar Photovoltaic Output & Surplus/Shortage Calculations'''
    total_days_shortage = 0
    total_days_surplus = 0

    battery_state = 0  # Start at neutral (or start at full capacity if preferred)
    battery_states = []

    for hour in range(24):
        load_for_the_hour_Wh = (load_day.iloc[hour,1]) * 1000000
        hour_GHI_Wh_m2 = (ghi_day.iloc[hour,1])

        if hour_GHI_Wh_m2 > 0:
            hour_PV_output_MWh = (hour_GHI_Wh_m2 * PV_with_bonus * PR * final_PV_plant_m2) / 1000000
            diff = hour_PV_output_MWh - (load_for_the_hour_Wh / 1000000)

            if diff >= 0:
                total_days_surplus += diff
            else:
                total_days_shortage += abs(diff)

            print(
                f"{hour}: Solar PV output: {hour_PV_output_MWh:.3f} MWh & "
                f"Actual load: {load_for_the_hour_Wh / 1000000:.3f} MWh & "
                f"{'Surplus of ' if diff >= 0 else 'Shortage of -'}{abs(diff):.3f} MWh"
            )

            battery_state += diff
            battery_states.append(battery_state)

        else:
            shortage = load_for_the_hour_Wh / 1000000
            print(f'{hour}: Shortage of -{shortage:.3f} MWh')
            total_days_shortage += shortage
            battery_state -= shortage
            battery_states.append(battery_state)

    print(f'\nSurplus: {total_days_surplus:.3f} MWh in Solar PV going to Battery Storage')
    print(f'Shortage: {total_days_shortage:.3f} MWh either accessed from Battery Storage or NGCC')
    print(f'Battery states: {[f"{x:.3f}" for x in battery_states]}')

    '''Capacity of Battery'''
    # Battery capacity should cover the range from max to min state
    battery_capacity = max(battery_states) - min(battery_states)
    battery_capacity_list.append(battery_capacity)

    print(f'Required battery capacity: {battery_capacity:.3f} MWh')

# %%
''' Load Data for Representative Dates'''

import pandas as pd
import os

# Path to your seasonal file
save_directory = '/content/drive/MyDrive'
seasonal_file = os.path.join(save_directory, 'seasonal_predicted_loads.csv')

# Check if the file exists and is non-empty
if os.path.exists(seasonal_file) and os.path.getsize(seasonal_file) > 0:
    try:
        seasonal_load_df = pd.read_csv(seasonal_file)
        print("✅ Seasonal data loaded successfully!")
        print(seasonal_load_df)
    except pd.errors.EmptyDataError:
        print("⚠️ Seasonal file exists but is empty.")
        seasonal_load_df = pd.DataFrame()  # create empty DataFrame
else:
    print("⚠️ Seasonal file does not exist or is empty.")
    seasonal_load_df = pd.DataFrame()  # create empty DataFrame
# Out:
# ✅ Seasonal data loaded successfully!
#      hour  predicted_load        date
# 0       0     6730.208000  2025-03-21
# 1       1     6317.309600  2025-03-21
# 2       2     5992.536000  2025-03-21
# 3       3     5779.637700  2025-03-21
# 4       4     5609.925300  2025-03-21
# ..    ...             ...         ...
# 283    19     8018.749023  2025-02-21
# 284    20     8250.614258  2025-02-21
# 285    21     8259.625977  2025-02-21
# 286    22     8042.062500  2025-02-21
# 287    23     7776.392090  2025-02-21
#
# [288 rows x 3 columns]

# %%
''' Solar GHI Data for Representative Dates'''

import pandas as pd
import os

# Path to your seasonal file
save_directory = '/content/drive/MyDrive'
GHI_file = os.path.join(save_directory, 'seasonal_predicted_ghi.csv')

# Check if the file exists and is non-empty
if os.path.exists(GHI_file) and os.path.getsize(GHI_file) > 0:
    try:
        seasonal_ghi_df = pd.read_csv(GHI_file)
        print("✅ GHI data loaded successfully!")
        print(seasonal_ghi_df)
    except pd.errors.EmptyDataError:
        print("⚠️ GHI file exists but is empty.")
        seasonal_ghi_df = pd.DataFrame()  # create empty DataFrame
else:
    print("⚠️ GHI file does not exist or is empty.")
    seasonal_ghi_df = pd.DataFrame()  # create empty DataFrame
# Out:
# ✅ GHI data loaded successfully!
#      hour  predicted_ghi        date
# 0       0            0.0  2025-03-21
# 1       1            0.0  2025-03-21
# 2       2            0.0  2025-03-21
# 3       3            0.0  2025-03-21
# 4       4            0.0  2025-03-21
# ..    ...            ...         ...
# 283    19            0.0  2025-02-21
# 284    20            0.0  2025-02-21
# 285    21            0.0  2025-02-21
# 286    22            0.0  2025-02-21
# 287    23            0.0  2025-02-21
#
# [288 rows x 3 columns]

# %%
simulate_day("2025-03-21", seasonal_load_df, seasonal_ghi_df)
simulate_day("2025-04-21", seasonal_load_df, seasonal_ghi_df)
simulate_day("2025-05-21", seasonal_load_df, seasonal_ghi_df)

# print("--")
# print(battery_capacity_list)
# print(final_PV_plant_m2_list)
# Out:
# Solar PV Plant Size 186478332.01 m²
#
# 0: Shortage of -6730.208 MWh
# 1: Shortage of -6317.310 MWh
# 2: Shortage of -5992.536 MWh
# 3: Shortage of -5779.638 MWh
# 4: Shortage of -5609.925 MWh
# 5: Shortage of -5574.014 MWh
# 6: Shortage of -5655.417 MWh
# 7: Solar PV output: 622.828 MWh & Actual load: 5845.335 MWh & Shortage of -5222.507 MWh
# 8: Solar PV output: 4844.082 MWh & Actual load: 6086.470 MWh & Shortage of -1242.388 MWh
# 9: Solar PV output: 8154.823 MWh & Actual load: 6405.889 MWh & Surplus of 1748.934 MWh
# 10: Solar PV output: 11872.923 MWh & Actual load: 6707.161 MWh & Surplus of 5165.762 MWh
# 11: Solar PV output: 14882.075 MWh & Actual load: 6735.973 MWh & Surplus of 8146.102 MWh
# 12: Solar PV output: 19930.251 MWh & Actual load: 6783.007 MWh & Surplus of 13147.244 MWh
# 13: Solar PV output: 21620.407 MWh & Actual load: 6813.663 MWh & Surplus of 14806.744 MWh
# 14: Solar PV output: 21946.117 MWh & Actual load: 6976.355 MWh & Surplus of 14969.762 MWh
# 15: Solar PV output: 19898.112 MWh & Actual load: 7056.002 MWh & Surplus of 12842.110 MWh
# 16: Solar PV output: 16987.160 MWh & Actual load: 7197.445 MWh & Surplus of 9789.714 MWh
# 17: Solar PV output: 12533.604 MWh & Actual load: 7427.610 MWh & Surplus of 5105.993 MWh
# 18: Solar PV output: 6719.622 MWh & Actual load: 7645.655 MWh & Shortage of -926.034 MWh
# 19: Solar PV output: 604.421 MWh & Actual load: 7702.862 MWh & Shortage of -7098.442 MWh
# 20: Shortage of -7702.962 MWh
# 21: Shortage of -7630.895 MWh
# 22: Shortage of -7330.643 MWh
# 23: Shortage of -6909.449 MWh
#
# Surplus: 85722.367 MWh in Solar PV going to Battery Storage
# Shortage: 85722.367 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-6730.208', '-13047.518', '-19040.054', '-24819.691', '-30429.617', '-36003.631', '-41659.047', '-46881.554', '-48123.942', '-46375.008', '-41209.246', '-33063.144', '-19915.899', '-5109.156', '9860.607', '22702.717', '32492.431', '37598.425', '36672.391', '29573.950', '21870.988', '14240.092', '6909.449', '0.000']
# Required battery capacity: 85722.367 MWh
# Solar PV Plant Size 165103479.90 m²
#
# 0: Shortage of -7200.700 MWh
# 1: Shortage of -6736.832 MWh
# 2: Shortage of -6410.007 MWh
# 3: Shortage of -6192.804 MWh
# 4: Shortage of -6070.165 MWh
# 5: Shortage of -6081.433 MWh
# 6: Shortage of -6302.160 MWh
# 7: Solar PV output: 1328.260 MWh & Actual load: 6693.363 MWh & Shortage of -5365.103 MWh
# 8: Solar PV output: 4841.033 MWh & Actual load: 7018.984 MWh & Shortage of -2177.952 MWh
# 9: Solar PV output: 8410.623 MWh & Actual load: 7255.932 MWh & Surplus of 1154.692 MWh
# 10: Solar PV output: 12487.357 MWh & Actual load: 7461.294 MWh & Surplus of 5026.063 MWh
# 11: Solar PV output: 19039.009 MWh & Actual load: 7721.686 MWh & Surplus of 11317.323 MWh
# 12: Solar PV output: 23678.865 MWh & Actual load: 7906.391 MWh & Surplus of 15772.474 MWh
# 13: Solar PV output: 25935.015 MWh & Actual load: 8194.820 MWh & Surplus of 17740.195 MWh
# 14: Solar PV output: 25682.301 MWh & Actual load: 8464.417 MWh & Surplus of 17217.884 MWh
# 15: Solar PV output: 23189.095 MWh & Actual load: 8814.011 MWh & Surplus of 14375.084 MWh
# 16: Solar PV output: 19187.379 MWh & Actual load: 9086.769 MWh & Surplus of 10100.611 MWh
# 17: Solar PV output: 13826.896 MWh & Actual load: 9354.405 MWh & Surplus of 4472.491 MWh
# 18: Solar PV output: 7639.082 MWh & Actual load: 9537.706 MWh & Shortage of -1898.624 MWh
# 19: Solar PV output: 1964.381 MWh & Actual load: 9476.333 MWh & Shortage of -7511.952 MWh
# 20: Shortage of -9295.021 MWh
# 21: Shortage of -9110.328 MWh
# 22: Shortage of -8651.941 MWh
# 23: Shortage of -8171.793 MWh
#
# Surplus: 97176.815 MWh in Solar PV going to Battery Storage
# Shortage: 97176.815 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-7200.700', '-13937.532', '-20347.539', '-26540.343', '-32610.508', '-38691.941', '-44994.101', '-50359.204', '-52537.156', '-51382.464', '-46356.401', '-35039.078', '-19266.604', '-1526.410', '15691.474', '30066.558', '40167.169', '44639.660', '42741.036', '35229.083', '25934.063', '16823.735', '8171.793', '0.000']
# Required battery capacity: 97176.815 MWh
# Solar PV Plant Size 170905644.02 m²
#
# 0: Shortage of -8501.134 MWh
# 1: Shortage of -7959.561 MWh
# 2: Shortage of -7503.872 MWh
# 3: Shortage of -7154.127 MWh
# 4: Shortage of -7013.054 MWh
# 5: Shortage of -7041.674 MWh
# 6: Shortage of -7194.072 MWh
# 7: Solar PV output: 2491.666 MWh & Actual load: 7498.557 MWh & Shortage of -5006.891 MWh
# 8: Solar PV output: 6374.651 MWh & Actual load: 7755.388 MWh & Shortage of -1380.737 MWh
# 9: Solar PV output: 11590.032 MWh & Actual load: 8039.989 MWh & Surplus of 3550.043 MWh
# 10: Solar PV output: 16746.180 MWh & Actual load: 8349.980 MWh & Surplus of 8396.200 MWh
# 11: Solar PV output: 23412.704 MWh & Actual load: 8740.856 MWh & Surplus of 14671.848 MWh
# 12: Solar PV output: 25732.827 MWh & Actual load: 9254.486 MWh & Surplus of 16478.341 MWh
# 13: Solar PV output: 26994.208 MWh & Actual load: 9672.195 MWh & Surplus of 17322.013 MWh
# 14: Solar PV output: 26951.267 MWh & Actual load: 10036.069 MWh & Surplus of 16915.198 MWh
# 15: Solar PV output: 25247.758 MWh & Actual load: 10447.291 MWh & Surplus of 14800.467 MWh
# 16: Solar PV output: 22958.416 MWh & Actual load: 10821.093 MWh & Surplus of 12137.323 MWh
# 17: Solar PV output: 16880.072 MWh & Actual load: 11074.542 MWh & Surplus of 5805.530 MWh
# 18: Solar PV output: 10045.921 MWh & Actual load: 11339.944 MWh & Shortage of -1294.024 MWh
# 19: Solar PV output: 3524.331 MWh & Actual load: 11352.362 MWh & Shortage of -7828.031 MWh
# 20: Shortage of -11154.591 MWh
# 21: Shortage of -10758.621 MWh
# 22: Shortage of -10431.042 MWh
# 23: Shortage of -9855.533 MWh
#
# Surplus: 110076.962 MWh in Solar PV going to Battery Storage
# Shortage: 110076.962 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-8501.134', '-16460.694', '-23964.566', '-31118.693', '-38131.747', '-45173.420', '-52367.492', '-57374.383', '-58755.120', '-55205.077', '-46808.877', '-32137.030', '-15658.689', '1663.324', '18578.522', '33378.989', '45516.312', '51321.842', '50027.818', '42199.787', '31045.196', '20286.575', '9855.533', '-0.000']
# Required battery capacity: 110076.962 MWh

# %%
simulate_day("2025-06-21", seasonal_load_df, seasonal_ghi_df)
simulate_day("2025-07-21", seasonal_load_df, seasonal_ghi_df)
simulate_day("2025-08-21", seasonal_load_df, seasonal_ghi_df)

# print("--")
# print(battery_capacity_list)
# print(final_PV_plant_m2_list)
# Out:
# Solar PV Plant Size 158689228.94 m²
#
# 0: Shortage of -10040.786 MWh
# 1: Shortage of -9209.105 MWh
# 2: Shortage of -8607.014 MWh
# 3: Shortage of -8225.139 MWh
# 4: Shortage of -7970.303 MWh
# 5: Shortage of -7622.427 MWh
# 6: Shortage of -7478.985 MWh
# 7: Solar PV output: 2812.428 MWh & Actual load: 7438.935 MWh & Shortage of -4626.507 MWh
# 8: Solar PV output: 7735.044 MWh & Actual load: 7602.401 MWh & Surplus of 132.643 MWh
# 9: Solar PV output: 13090.135 MWh & Actual load: 8006.682 MWh & Surplus of 5083.453 MWh
# 10: Solar PV output: 20157.509 MWh & Actual load: 8403.241 MWh & Surplus of 11754.268 MWh
# 11: Solar PV output: 24960.216 MWh & Actual load: 9075.121 MWh & Surplus of 15885.094 MWh
# 12: Solar PV output: 28078.278 MWh & Actual load: 9823.237 MWh & Surplus of 18255.041 MWh
# 13: Solar PV output: 28892.244 MWh & Actual load: 10528.911 MWh & Surplus of 18363.333 MWh
# 14: Solar PV output: 28911.521 MWh & Actual load: 11088.818 MWh & Surplus of 17822.703 MWh
# 15: Solar PV output: 26697.257 MWh & Actual load: 11531.290 MWh & Surplus of 15165.967 MWh
# 16: Solar PV output: 22751.915 MWh & Actual load: 11944.994 MWh & Surplus of 10806.921 MWh
# 17: Solar PV output: 17653.361 MWh & Actual load: 12306.399 MWh & Surplus of 5346.961 MWh
# 18: Solar PV output: 11158.927 MWh & Actual load: 12455.347 MWh & Shortage of -1296.419 MWh
# 19: Solar PV output: 4972.597 MWh & Actual load: 12487.698 MWh & Shortage of -7515.101 MWh
# 20: Solar PV output: 461.036 MWh & Actual load: 12294.961 MWh & Shortage of -11833.925 MWh
# 21: Shortage of -11904.165 MWh
# 22: Shortage of -11497.569 MWh
# 23: Shortage of -10788.938 MWh
#
# Surplus: 118616.384 MWh in Solar PV going to Battery Storage
# Shortage: 118616.384 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-10040.786', '-19249.892', '-27856.905', '-36082.044', '-44052.347', '-51674.773', '-59153.758', '-63780.265', '-63647.623', '-58564.169', '-46809.901', '-30924.806', '-12669.766', '5693.567', '23516.270', '38682.237', '49489.157', '54836.119', '53539.699', '46024.598', '34190.673', '22286.508', '10788.938', '-0.000']
# Required battery capacity: 118616.384 MWh
# Solar PV Plant Size 170272447.04 m²
#
# 0: Shortage of -10578.646 MWh
# 1: Shortage of -9802.232 MWh
# 2: Shortage of -9197.294 MWh
# 3: Shortage of -8733.183 MWh
# 4: Shortage of -8480.444 MWh
# 5: Shortage of -8340.062 MWh
# 6: Shortage of -8366.530 MWh
# 7: Solar PV output: 2600.811 MWh & Actual load: 8478.548 MWh & Shortage of -5877.736 MWh
# 8: Solar PV output: 8013.045 MWh & Actual load: 8778.097 MWh & Shortage of -765.052 MWh
# 9: Solar PV output: 14672.043 MWh & Actual load: 9187.220 MWh & Surplus of 5484.823 MWh
# 10: Solar PV output: 22647.681 MWh & Actual load: 9780.154 MWh & Surplus of 12867.527 MWh
# 11: Solar PV output: 27844.701 MWh & Actual load: 10500.417 MWh & Surplus of 17344.284 MWh
# 12: Solar PV output: 31392.365 MWh & Actual load: 11113.274 MWh & Surplus of 20279.090 MWh
# 13: Solar PV output: 32479.359 MWh & Actual load: 11843.940 MWh & Surplus of 20635.419 MWh
# 14: Solar PV output: 31242.362 MWh & Actual load: 12397.075 MWh & Surplus of 18845.287 MWh
# 15: Solar PV output: 28659.207 MWh & Actual load: 12804.791 MWh & Surplus of 15854.416 MWh
# 16: Solar PV output: 24358.805 MWh & Actual load: 13170.458 MWh & Surplus of 11188.347 MWh
# 17: Solar PV output: 19004.855 MWh & Actual load: 13376.385 MWh & Surplus of 5628.471 MWh
# 18: Solar PV output: 12057.862 MWh & Actual load: 13282.873 MWh & Shortage of -1225.011 MWh
# 19: Solar PV output: 4893.744 MWh & Actual load: 13138.958 MWh & Shortage of -8245.214 MWh
# 20: Shortage of -12816.450 MWh
# 21: Shortage of -12445.376 MWh
# 22: Shortage of -11959.351 MWh
# 23: Shortage of -11295.082 MWh
#
# Surplus: 128127.665 MWh in Solar PV going to Battery Storage
# Shortage: 128127.665 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-10578.646', '-20380.879', '-29578.173', '-38311.355', '-46791.800', '-55131.862', '-63498.393', '-69376.129', '-70141.181', '-64656.358', '-51788.831', '-34444.547', '-14165.456', '6469.963', '25315.250', '41169.666', '52358.013', '57986.484', '56761.473', '48516.259', '35699.809', '23254.433', '11295.082', '-0.000']
# Required battery capacity: 128127.665 MWh
# Solar PV Plant Size 169187395.13 m²
#
# 0: Shortage of -10428.392 MWh
# 1: Shortage of -9719.900 MWh
# 2: Shortage of -9125.285 MWh
# 3: Shortage of -8750.827 MWh
# 4: Shortage of -8567.454 MWh
# 5: Shortage of -8495.716 MWh
# 6: Shortage of -8587.397 MWh
# 7: Solar PV output: 2584.238 MWh & Actual load: 8658.175 MWh & Shortage of -6073.937 MWh
# 8: Solar PV output: 7961.982 MWh & Actual load: 8842.336 MWh & Shortage of -880.354 MWh
# 9: Solar PV output: 14578.546 MWh & Actual load: 9216.081 MWh & Surplus of 5362.465 MWh
# 10: Solar PV output: 22503.360 MWh & Actual load: 9643.122 MWh & Surplus of 12860.238 MWh
# 11: Solar PV output: 27667.262 MWh & Actual load: 10281.702 MWh & Surplus of 17385.560 MWh
# 12: Solar PV output: 31192.319 MWh & Actual load: 11006.195 MWh & Surplus of 20186.123 MWh
# 13: Solar PV output: 32272.386 MWh & Actual load: 11766.372 MWh & Surplus of 20506.014 MWh
# 14: Solar PV output: 31043.272 MWh & Actual load: 12403.604 MWh & Surplus of 18639.668 MWh
# 15: Solar PV output: 28476.578 MWh & Actual load: 12874.376 MWh & Surplus of 15602.202 MWh
# 16: Solar PV output: 24203.580 MWh & Actual load: 12997.625 MWh & Surplus of 11205.955 MWh
# 17: Solar PV output: 18883.748 MWh & Actual load: 13002.088 MWh & Surplus of 5881.660 MWh
# 18: Solar PV output: 11981.024 MWh & Actual load: 13080.997 MWh & Shortage of -1099.973 MWh
# 19: Solar PV output: 4862.559 MWh & Actual load: 12800.794 MWh & Shortage of -7938.235 MWh
# 20: Shortage of -12637.917 MWh
# 21: Shortage of -12267.261 MWh
# 22: Shortage of -11800.481 MWh
# 23: Shortage of -11256.756 MWh
#
# Surplus: 127629.886 MWh in Solar PV going to Battery Storage
# Shortage: 127629.886 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-10428.392', '-20148.292', '-29273.577', '-38024.404', '-46591.858', '-55087.574', '-63674.972', '-69748.909', '-70629.262', '-65266.798', '-52406.559', '-35020.999', '-14834.876', '5671.138', '24310.806', '39913.008', '51118.963', '57000.623', '55900.650', '47962.415', '35324.498', '23057.237', '11256.756', '0.000']
# Required battery capacity: 127629.886 MWh

# %%
simulate_day("2025-09-21", seasonal_load_df, seasonal_ghi_df)
simulate_day("2025-10-21", seasonal_load_df, seasonal_ghi_df)
simulate_day("2025-11-21", seasonal_load_df, seasonal_ghi_df)

# print("--")
# print(battery_capacity_list)
# print(final_PV_plant_m2_list)
# Out:
# Solar PV Plant Size 189546653.38 m²
#
# 0: Shortage of -8827.731 MWh
# 1: Shortage of -8146.844 MWh
# 2: Shortage of -7746.161 MWh
# 3: Shortage of -7347.417 MWh
# 4: Shortage of -7165.840 MWh
# 5: Shortage of -7210.750 MWh
# 6: Shortage of -7434.976 MWh
# 7: Solar PV output: 878.316 MWh & Actual load: 7739.969 MWh & Shortage of -6861.652 MWh
# 8: Solar PV output: 5741.924 MWh & Actual load: 7886.763 MWh & Shortage of -2144.839 MWh
# 9: Solar PV output: 12562.551 MWh & Actual load: 8241.268 MWh & Surplus of 4321.283 MWh
# 10: Solar PV output: 18340.790 MWh & Actual load: 8642.458 MWh & Surplus of 9698.332 MWh
# 11: Solar PV output: 27501.977 MWh & Actual load: 9059.108 MWh & Surplus of 18442.869 MWh
# 12: Solar PV output: 31626.294 MWh & Actual load: 9587.666 MWh & Surplus of 22038.628 MWh
# 13: Solar PV output: 31383.000 MWh & Actual load: 10072.087 MWh & Surplus of 21310.913 MWh
# 14: Solar PV output: 29104.692 MWh & Actual load: 10523.706 MWh & Surplus of 18580.986 MWh
# 15: Solar PV output: 26020.066 MWh & Actual load: 10863.758 MWh & Surplus of 15156.308 MWh
# 16: Solar PV output: 21302.892 MWh & Actual load: 11348.406 MWh & Surplus of 9954.485 MWh
# 17: Solar PV output: 14057.250 MWh & Actual load: 11625.257 MWh & Surplus of 2431.993 MWh
# 18: Solar PV output: 6202.793 MWh & Actual load: 11757.396 MWh & Shortage of -5554.602 MWh
# 19: Solar PV output: 13.669 MWh & Actual load: 11566.341 MWh & Shortage of -11552.672 MWh
# 20: Shortage of -11183.799 MWh
# 21: Shortage of -10910.707 MWh
# 22: Shortage of -10273.448 MWh
# 23: Shortage of -9574.361 MWh
#
# Surplus: 121935.798 MWh in Solar PV going to Battery Storage
# Shortage: 121935.798 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-8827.731', '-16974.575', '-24720.736', '-32068.153', '-39233.993', '-46444.742', '-53879.718', '-60741.370', '-62886.209', '-58564.926', '-48866.594', '-30423.725', '-8385.097', '12925.816', '31506.802', '46663.111', '56617.596', '59049.589', '53494.987', '41942.315', '30758.517', '19847.810', '9574.361', '0.000']
# Required battery capacity: 121935.798 MWh
# Solar PV Plant Size 207029721.73 m²
#
# 0: Shortage of -7361.230 MWh
# 1: Shortage of -6882.203 MWh
# 2: Shortage of -6492.642 MWh
# 3: Shortage of -6184.093 MWh
# 4: Shortage of -6052.621 MWh
# 5: Shortage of -6042.731 MWh
# 6: Shortage of -6267.856 MWh
# 7: Shortage of -6594.498 MWh
# 8: Solar PV output: 5345.649 MWh & Actual load: 6801.059 MWh & Shortage of -1455.409 MWh
# 9: Solar PV output: 12161.011 MWh & Actual load: 6955.214 MWh & Surplus of 5205.797 MWh
# 10: Solar PV output: 15826.130 MWh & Actual load: 7072.979 MWh & Surplus of 8753.151 MWh
# 11: Solar PV output: 21969.317 MWh & Actual load: 7262.780 MWh & Surplus of 14706.538 MWh
# 12: Solar PV output: 27508.615 MWh & Actual load: 7482.630 MWh & Surplus of 20025.986 MWh
# 13: Solar PV output: 26533.367 MWh & Actual load: 7751.381 MWh & Surplus of 18781.986 MWh
# 14: Solar PV output: 25379.141 MWh & Actual load: 8052.688 MWh & Surplus of 17326.453 MWh
# 15: Solar PV output: 21506.350 MWh & Actual load: 8439.156 MWh & Surplus of 13067.194 MWh
# 16: Solar PV output: 15350.178 MWh & Actual load: 8747.594 MWh & Surplus of 6602.584 MWh
# 17: Solar PV output: 7358.656 MWh & Actual load: 8922.573 MWh & Shortage of -1563.917 MWh
# 18: Solar PV output: 1602.189 MWh & Actual load: 8976.394 MWh & Shortage of -7374.205 MWh
# 19: Shortage of -8880.831 MWh
# 20: Shortage of -8824.099 MWh
# 21: Shortage of -8673.024 MWh
# 22: Shortage of -8145.401 MWh
# 23: Shortage of -7674.928 MWh
#
# Surplus: 104469.689 MWh in Solar PV going to Battery Storage
# Shortage: 104469.689 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-7361.230', '-14243.434', '-20736.075', '-26920.168', '-32972.789', '-39015.520', '-45283.376', '-51877.874', '-53333.283', '-48127.486', '-39374.334', '-24667.797', '-4641.811', '14140.174', '31466.628', '44533.821', '51136.406', '49572.488', '42198.283', '33317.452', '24493.354', '15820.329', '7674.928', '-0.000']
# Required battery capacity: 104469.689 MWh
# Solar PV Plant Size 325727642.24 m²
#
# 0: Shortage of -6346.693 MWh
# 1: Shortage of -6044.607 MWh
# 2: Shortage of -5788.213 MWh
# 3: Shortage of -5621.755 MWh
# 4: Shortage of -5514.288 MWh
# 5: Shortage of -5528.925 MWh
# 6: Shortage of -5705.197 MWh
# 7: Solar PV output: 1375.656 MWh & Actual load: 5990.682 MWh & Shortage of -4615.026 MWh
# 8: Solar PV output: 7742.691 MWh & Actual load: 6254.149 MWh & Surplus of 1488.542 MWh
# 9: Solar PV output: 14259.909 MWh & Actual load: 6507.517 MWh & Surplus of 7752.393 MWh
# 10: Solar PV output: 19202.259 MWh & Actual load: 6656.417 MWh & Surplus of 12545.842 MWh
# 11: Solar PV output: 21218.755 MWh & Actual load: 6707.181 MWh & Surplus of 14511.575 MWh
# 12: Solar PV output: 25125.117 MWh & Actual load: 6649.495 MWh & Surplus of 18475.622 MWh
# 13: Solar PV output: 22080.402 MWh & Actual load: 6566.197 MWh & Surplus of 15514.205 MWh
# 14: Solar PV output: 19954.133 MWh & Actual load: 6591.665 MWh & Surplus of 13362.468 MWh
# 15: Solar PV output: 13423.667 MWh & Actual load: 6598.825 MWh & Surplus of 6824.842 MWh
# 16: Solar PV output: 7594.879 MWh & Actual load: 6652.436 MWh & Surplus of 942.444 MWh
# 17: Solar PV output: 1786.098 MWh & Actual load: 6751.147 MWh & Shortage of -4965.049 MWh
# 18: Shortage of -6862.064 MWh
# 19: Shortage of -7032.264 MWh
# 20: Shortage of -7140.318 MWh
# 21: Shortage of -7068.608 MWh
# 22: Shortage of -6782.360 MWh
# 23: Shortage of -6402.562 MWh
#
# Surplus: 91417.931 MWh in Solar PV going to Battery Storage
# Shortage: 91417.931 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-6346.693', '-12391.301', '-18179.514', '-23801.269', '-29315.557', '-34844.481', '-40549.679', '-45164.705', '-43676.163', '-35923.770', '-23377.928', '-8866.353', '9609.269', '25123.473', '38485.941', '45310.783', '46253.226', '41288.177', '34426.112', '27393.849', '20253.530', '13184.922', '6402.562', '0.000']
# Required battery capacity: 91417.931 MWh

# %%
simulate_day("2025-12-21", seasonal_load_df, seasonal_ghi_df)
simulate_day("2025-01-21", seasonal_load_df, seasonal_ghi_df)
simulate_day("2025-02-21", seasonal_load_df, seasonal_ghi_df)

# print("--")
# print(battery_capacity_list)
# print(final_PV_plant_m2_list)
# Out:
# Solar PV Plant Size 318363810.02 m²
#
# 0: Shortage of -6590.680 MWh
# 1: Shortage of -6419.684 MWh
# 2: Shortage of -6270.017 MWh
# 3: Shortage of -6161.588 MWh
# 4: Shortage of -6253.072 MWh
# 5: Shortage of -6415.909 MWh
# 6: Shortage of -6880.918 MWh
# 7: Solar PV output: 792.758 MWh & Actual load: 7534.108 MWh & Shortage of -6741.350 MWh
# 8: Solar PV output: 7143.825 MWh & Actual load: 7992.439 MWh & Shortage of -848.614 MWh
# 9: Solar PV output: 13524.272 MWh & Actual load: 7997.808 MWh & Surplus of 5526.465 MWh
# 10: Solar PV output: 19118.565 MWh & Actual load: 7715.731 MWh & Surplus of 11402.833 MWh
# 11: Solar PV output: 24459.511 MWh & Actual load: 7430.483 MWh & Surplus of 17029.028 MWh
# 12: Solar PV output: 31635.022 MWh & Actual load: 7292.448 MWh & Surplus of 24342.574 MWh
# 13: Solar PV output: 31449.426 MWh & Actual load: 7249.138 MWh & Surplus of 24200.289 MWh
# 14: Solar PV output: 22922.805 MWh & Actual load: 7160.491 MWh & Surplus of 15762.314 MWh
# 15: Solar PV output: 13302.056 MWh & Actual load: 7107.867 MWh & Surplus of 6194.189 MWh
# 16: Solar PV output: 7173.895 MWh & Actual load: 7099.270 MWh & Surplus of 74.625 MWh
# 17: Solar PV output: 1184.863 MWh & Actual load: 7274.289 MWh & Shortage of -6089.426 MWh
# 18: Shortage of -7533.199 MWh
# 19: Shortage of -7792.575 MWh
# 20: Shortage of -7943.911 MWh
# 21: Shortage of -7784.840 MWh
# 22: Shortage of -7537.483 MWh
# 23: Shortage of -7269.052 MWh
#
# Surplus: 104532.317 MWh in Solar PV going to Battery Storage
# Shortage: 104532.317 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-6590.680', '-13010.363', '-19280.380', '-25441.968', '-31695.040', '-38110.949', '-44991.867', '-51733.217', '-52581.831', '-47055.366', '-35652.533', '-18623.505', '5719.069', '29919.358', '45681.671', '51875.861', '51950.486', '45861.061', '38327.861', '30535.286', '22591.375', '14806.535', '7269.052', '0.000']
# Required battery capacity: 104532.317 MWh
# Solar PV Plant Size 255184299.18 m²
#
# 0: Shortage of -7065.181 MWh
# 1: Shortage of -6878.719 MWh
# 2: Shortage of -6736.534 MWh
# 3: Shortage of -6692.933 MWh
# 4: Shortage of -6803.519 MWh
# 5: Shortage of -7077.093 MWh
# 6: Shortage of -7628.392 MWh
# 7: Shortage of -8325.940 MWh
# 8: Solar PV output: 5665.706 MWh & Actual load: 8712.828 MWh & Shortage of -3047.122 MWh
# 9: Solar PV output: 13194.339 MWh & Actual load: 8556.231 MWh & Surplus of 4638.108 MWh
# 10: Solar PV output: 22132.256 MWh & Actual load: 8274.718 MWh & Surplus of 13857.539 MWh
# 11: Solar PV output: 28155.024 MWh & Actual load: 7967.118 MWh & Surplus of 20187.906 MWh
# 12: Solar PV output: 27997.388 MWh & Actual load: 7760.883 MWh & Surplus of 20236.505 MWh
# 13: Solar PV output: 28492.927 MWh & Actual load: 7580.022 MWh & Surplus of 20912.905 MWh
# 14: Solar PV output: 27706.554 MWh & Actual load: 7389.608 MWh & Surplus of 20316.946 MWh
# 15: Solar PV output: 18522.091 MWh & Actual load: 7307.254 MWh & Surplus of 11214.837 MWh
# 16: Solar PV output: 9507.754 MWh & Actual load: 7295.008 MWh & Surplus of 2212.747 MWh
# 17: Solar PV output: 2236.518 MWh & Actual load: 7464.496 MWh & Shortage of -5227.977 MWh
# 18: Shortage of -7746.639 MWh
# 19: Shortage of -8018.749 MWh
# 20: Shortage of -8250.614 MWh
# 21: Shortage of -8259.626 MWh
# 22: Shortage of -8042.062 MWh
# 23: Shortage of -7776.392 MWh
#
# Surplus: 113577.492 MWh in Solar PV going to Battery Storage
# Shortage: 113577.492 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-7065.181', '-13943.900', '-20680.434', '-27373.367', '-34176.886', '-41253.979', '-48882.370', '-57208.311', '-60255.432', '-55617.325', '-41759.786', '-21571.880', '-1335.375', '19577.530', '39894.476', '51109.313', '53322.060', '48094.083', '40347.444', '32328.695', '24078.081', '15818.455', '7776.392', '0.000']
# Required battery capacity: 113577.492 MWh
# Solar PV Plant Size 254765025.24 m²
#
# 0: Shortage of -7065.181 MWh
# 1: Shortage of -6878.719 MWh
# 2: Shortage of -6736.534 MWh
# 3: Shortage of -6692.933 MWh
# 4: Shortage of -6803.519 MWh
# 5: Shortage of -7077.093 MWh
# 6: Shortage of -7628.392 MWh
# 7: Shortage of -8325.940 MWh
# 8: Solar PV output: 5467.760 MWh & Actual load: 8712.828 MWh & Shortage of -3245.068 MWh
# 9: Solar PV output: 10901.030 MWh & Actual load: 8556.231 MWh & Surplus of 2344.799 MWh
# 10: Solar PV output: 16248.069 MWh & Actual load: 8274.718 MWh & Surplus of 7973.351 MWh
# 11: Solar PV output: 23693.416 MWh & Actual load: 7967.118 MWh & Surplus of 15726.298 MWh
# 12: Solar PV output: 27130.612 MWh & Actual load: 7760.883 MWh & Surplus of 19369.729 MWh
# 13: Solar PV output: 27991.924 MWh & Actual load: 7580.022 MWh & Surplus of 20411.902 MWh
# 14: Solar PV output: 27958.900 MWh & Actual load: 7389.608 MWh & Surplus of 20569.292 MWh
# 15: Solar PV output: 23785.488 MWh & Actual load: 7307.254 MWh & Surplus of 16478.234 MWh
# 16: Solar PV output: 14477.979 MWh & Actual load: 7295.008 MWh & Surplus of 7182.971 MWh
# 17: Solar PV output: 5955.381 MWh & Actual load: 7464.496 MWh & Shortage of -1509.114 MWh
# 18: Shortage of -7746.639 MWh
# 19: Shortage of -8018.749 MWh
# 20: Shortage of -8250.614 MWh
# 21: Shortage of -8259.626 MWh
# 22: Shortage of -8042.062 MWh
# 23: Shortage of -7776.392 MWh
#
# Surplus: 110056.575 MWh in Solar PV going to Battery Storage
# Shortage: 110056.575 MWh either accessed from Battery Storage or NGCC
# Battery states: ['-7065.181', '-13943.900', '-20680.434', '-27373.367', '-34176.886', '-41253.979', '-48882.370', '-57208.311', '-60453.378', '-58108.580', '-50135.229', '-34408.931', '-15039.202', '5372.700', '25941.992', '42420.226', '49603.197', '48094.083', '40347.444', '32328.695', '24078.081', '15818.455', '7776.392', '0.000']
# Required battery capacity: 110056.575 MWh

# %%
final_battery_size = sum(battery_capacity_list) / len(battery_capacity_list)
final_PV_plant_size = sum(final_PV_plant_m2_list) / len(final_PV_plant_m2_list)

print(f"Final Averaged Battery Capacity: {final_battery_size}")
print(f"Final Averaged PV Plant Size: {final_PV_plant_size}")
# Out:
# Final Averaged Battery Capacity: 109444.99001391667
# Final Averaged PV Plant Size: 214271139.90200898

# %% [markdown]
# # Calculating TODAY'S Information

# %%
'''Today's Hourly Solar PV Output & Surplus/Shortage Calculations'''

amt_in_battery = 0
fossil_used = 0
solar_wasted = 0
solar_produced = 0

for hour in range(24):
    load_for_the_hour_Wh = (load_df.iloc[hour, 1]) * 1000000
    hour_GHI_Wh_m2 = (ghi_df.iloc[hour, 1])

    PV_with_bonus = 0.20 * 1.31
    PR = 0.786

    if hour_GHI_Wh_m2 > 0:
        hour_PV_output_MWh = (hour_GHI_Wh_m2 * PV_with_bonus * PR * final_PV_plant_size) / 1000000
        diff = hour_PV_output_MWh - (load_for_the_hour_Wh / 1000000)
        solar_produced += hour_PV_output_MWh

        print(
            f"{hour}: The Solar PV output: {hour_PV_output_MWh} MWh, "
            f"Actual load: {load_for_the_hour_Wh / 1000000} MWh, "
            f"{'Surplus of ' if diff >= 0 else 'Shortage of -'}{abs(diff)} MWh"
        )

        if diff >= 0:  # surplus → store in battery
            available_space = final_battery_size - amt_in_battery
            charge = min(diff, available_space)
            amt_in_battery += charge
            solar_wasted += max(0, diff - charge)  # if battery full, waste rest

        else:  # shortage → draw from battery
            needed = abs(diff)
            discharge = min(needed, amt_in_battery)
            amt_in_battery -= discharge
            fossil_used += max(0, needed - discharge)  # if battery empty, use fossil
    else:
        shortage = load_for_the_hour_Wh / 1000000
        print(f"{hour}: Shortage of -{shortage} MWh")

        discharge = min(shortage, amt_in_battery)
        amt_in_battery -= discharge
        fossil_used += max(0, shortage - discharge)

print()
print(f"{amt_in_battery} MWh remaining in the Battery Storage")
print(f"{solar_wasted} MWh of solar energy wasted (battery full)")
print(f"{fossil_used} MWh supplied by fossil fuels (battery empty)")
# Out:
# 0: Shortage of -7685.093 MWh
# 1: Shortage of -7156.707 MWh
# 2: Shortage of -6732.706 MWh
# 3: Shortage of -6442.014 MWh
# 4: Shortage of -6328.8784 MWh
# 5: Shortage of -6341.022 MWh
# 6: Shortage of -6510.8657 MWh
# 7: The Solar PV output: 2894.5012822224576 MWh, Actual load: 6838.9023 MWh, Shortage of -3944.401017777542 MWh
# 8: The Solar PV output: 7698.250228072955 MWh, Actual load: 7046.949 MWh, Surplus of 651.3012280729554 MWh
# 9: The Solar PV output: 13159.067901154602 MWh, Actual load: 7328.2065 MWh, Surplus of 5830.8614011546015 MWh
# 10: The Solar PV output: 19566.950082956315 MWh, Actual load: 7572.7905 MWh, Surplus of 11994.159582956316 MWh
# 11: The Solar PV output: 24716.319143788056 MWh, Actual load: 7843.742 MWh, Surplus of 16872.577143788054 MWh
# 12: The Solar PV output: 28210.59158896556 MWh, Actual load: 8167.2134 MWh, Surplus of 20043.37818896556 MWh
# 13: The Solar PV output: 28630.09066758809 MWh, Actual load: 8484.896 MWh, Surplus of 20145.19466758809 MWh
# 14: The Solar PV output: 26781.73677891331 MWh, Actual load: 8830.728 MWh, Surplus of 17951.00877891331 MWh
# 15: The Solar PV output: 21692.99453506432 MWh, Actual load: 9254.688 MWh, Surplus of 12438.306535064321 MWh
# 16: The Solar PV output: 14393.097225579366 MWh, Actual load: 9659.067 MWh, Surplus of 4734.030225579367 MWh
# 17: The Solar PV output: 6941.850190663121 MWh, Actual load: 10019.447 MWh, Shortage of -3077.5968093368792 MWh
# 18: The Solar PV output: 1679.741645988582 MWh, Actual load: 10153.843 MWh, Shortage of -8474.101354011418 MWh
# 19: Shortage of -9991.49 MWh
# 20: Shortage of -9671.202 MWh
# 21: Shortage of -9373.929 MWh
# 22: Shortage of -8919.265 MWh
# 23: Shortage of -8334.597 MWh
#
# 51602.80885056836 MWh remaining in the Battery Storage
# 1215.8277381659009 MWh of solar energy wasted (battery full)
# 51141.68711777754 MWh supplied by fossil fuels (battery empty)

# %%
'''Calculation if everything was done by fossil fuels'''

total_load = load_df['predicted_load'].sum()
total_Co2_emissions_for_all_NGCC = total_load * 0.499
print(f'{total_Co2_emissions_for_all_NGCC} metric tons of CO₂ will be emitted with 100% NGCC')

'''Calculate actual fossil fuel emissions'''

actual_Co2_emissions = (fossil_used * 0.499) + (solar_produced * 0.1238)
print(f'{actual_Co2_emissions} metric tons of CO₂ will actually be emitted')

'''Offsetting'''

print(f'{total_Co2_emissions_for_all_NGCC-actual_Co2_emissions} metric tons of CO₂ are NOT being emitted!!')
percentage_decrease = ((total_Co2_emissions_for_all_NGCC - actual_Co2_emissions) / total_Co2_emissions_for_all_NGCC) * 100
print(f'{percentage_decrease:.2f}% decrease of CO₂ emissions')
# Out:
# 97149.43265819999 metric tons of CO₂ will be emitted with 100% NGCC
# 49829.71255111543 metric tons of CO₂ will actually be emitted
# 47319.72010708456 metric tons of CO₂ are NOT being emitted!!
# 48.71% decrease of CO₂ emissions
